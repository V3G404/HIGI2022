# %%
import pandas as pd

# %%
amd_data=pd.read_csv("/home/vegaal2021/Downloads/adm_data.csv")

# %%
amd_data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
amd_data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
amd_data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
amd_data.keys()
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
amd_data[amd_data['University Rating']>4]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 5             6        330          115                  5  4.5   3.0  9.34
# 22           23        328          116                  5  5.0   5.0  9.50
# 23           24        334          119                  5  5.0   4.5  9.70
# 24           25        336          119                  5  4.0   3.5  9.80
# 25           26        340          120                  5  4.5   4.5  9.60
# 26           27        322          109                  5  4.5   3.5  8.80
# 33           34        340          114                  5  4.0   4.0  9.60
# 34           35        331          112                  5  4.0   5.0  9.80
# 35           36        320          110                  5  5.0   5.0  9.20
# 44           45        326          113                  5  4.5   4.0  9.40
# 45           46        322          110                  5  5.0   4.0  9.10
# ...

# %%
amd_data = amd_data.drop("Serial No.", axis=1)

# %%
amd_data.tail(1)
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 399              0.95

# %%
amd_data.sample(10)
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 289        313          109                  3  4.0   3.5  9.00         0
# 137        316          100                  2  1.5   3.0  8.16         1
# 158        306          106                  2  2.0   2.5  8.14         0
# 68         318          109                  3  3.5   4.0  9.22         1
# 103        317          104                  2  4.5   4.0  8.47         0
# 364        313          102                  3  3.5   4.0  8.90         1
# 111        321          109                  4  4.0   4.0  8.68         1
# 244        314          107                  2  2.5   4.0  8.56         0
# 375        304          101                  2  2.0   2.5  7.66         0
# 261        312          104                  3  3.5   4.0  8.09         0
#
#      Chance of Admit
# 289              0.79
# 137              0.71
# 158              0.61
# 68               0.68
# 103              0.57
# ...

# %%
amd_data.shape
# Out:
# (400, 8)

# %%
amd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    int64
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %%
amd_data.describe() #de nuevo xd
# regresa percentiles, maximo, minimo, cuenta. decentiles NO, etc.
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# ...

# %%
Urating=amd_data["University Rating"].unique()

Urating.sort()

# %%
Urating
# Out:
# array([1, 2, 3, 4, 5])

# %%
rating1=amd_data[amd_data['University Rating']==1]
rating1
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 8          302          102                  1  2.0   1.5  8.00         0
# 28         295           93                  1  2.0   2.0  7.20         0
# 37         300          105                  1  1.0   2.0  7.80         0
# 38         304          105                  1  3.0   1.5  7.50         0
# 58         300           99                  1  3.0   2.0  6.80         1
# 79         294           93                  1  1.5   2.0  7.36         0
# 139        318          109                  1  3.5   3.5  9.12         0
# 159        297          100                  1  1.5   2.0  7.90         0
# 160        315          103                  1  1.5   2.0  7.86         0
# 161        298           99                  1  1.5   3.0  7.46         0
# 239        299          100                  1  1.5   2.0  7.89         0
# 240        296          101                  1  2.5   3.0  7.68         0
# ...

# %%
rating1.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating        SOP       LOR   \
# count   26.000000    26.000000               26.0  26.000000  26.000000
# mean   303.153846    99.076923                1.0   1.884615   2.211538
# std      7.918042     3.856663                0.0   0.739022   0.602878
# min    290.000000    92.000000                1.0   1.000000   1.000000
# 25%    298.000000    98.000000                1.0   1.500000   2.000000
# 50%    300.500000    99.000000                1.0   1.750000   2.000000
# 75%    311.000000   100.000000                1.0   2.000000   2.500000
# max    318.000000   109.000000                1.0   3.500000   3.500000
#
#             CGPA   Research  Chance of Admit
# count  26.000000  26.000000         26.000000
# mean    7.745769   0.192308          0.548077
# std     0.450992   0.401918          0.089220
# min     6.800000   0.000000          0.360000
# 25%     7.460000   0.000000          0.492500
# ...

# %%
rating1.mean()
# Out:
# GRE Score            303.153846
# TOEFL Score           99.076923
# University Rating      1.000000
# SOP                    1.884615
# LOR                    2.211538
# CGPA                   7.745769
# Research               0.192308
# Chance of Admit        0.548077
# dtype: float64

# %%
for x in range(1,5):
    rating=amd_data[amd_data['University Rating']==x]
    print(f"Para universidades con rating {x}")
    print(rating.mean())
# Out:
# Para universidades con rating 1
# GRE Score            303.153846
# TOEFL Score           99.076923
# University Rating      1.000000
# SOP                    1.884615
# LOR                    2.211538
# CGPA                   7.745769
# Research               0.192308
# Chance of Admit        0.548077
# dtype: float64
# Para universidades con rating 2
# GRE Score            309.177570
# TOEFL Score          103.523364
# University Rating      2.000000
# SOP                    2.705607
# LOR                    2.925234
# CGPA                   8.183738
# Research               0.299065
# Chance of Admit        0.625981
# dtype: float64
# Para universidades con rating 3
# GRE Score            315.954887
# TOEFL Score          106.887218
# University Rating      3.000000
# SOP                    3.364662
# LOR                    3.402256
# CGPA                   8.552256
# Research               0.533835
# Chance of Admit        0.711880
# dtype: float64
# ...

# %%
means_by_rating=amd_data.groupby(["University Rating"]).mean()
means_by_rating
# Out:
#                     GRE Score  TOEFL Score       SOP      LOR       CGPA  \
# University Rating
# 1                  303.153846    99.076923  1.884615  2.211538  7.745769
# 2                  309.177570   103.523364  2.705607  2.925234  8.183738
# 3                  315.954887   106.887218  3.364662  3.402256  8.552256
# 4                  324.824324   111.824324  4.108108  4.006757  9.021622
# 5                  328.333333   113.666667  4.500000  4.358333  9.291167
#
#                    Research  Chance of Admit
# University Rating
# 1                  0.192308          0.548077
# 2                  0.299065          0.625981
# 3                  0.533835          0.711880
# 4                  0.797297          0.818108
# 5                  0.866667          0.888167

# %%
#recomendada - exportar con código de latex

# %%
print(means_by_rating.style.to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
#  & GRE Score & TOEFL Score & SOP & LOR  & CGPA & Research & Chance of Admit  \\
# University Rating &  &  &  &  &  &  &  \\
# 1 & 303.153846 & 99.076923 & 1.884615 & 2.211538 & 7.745769 & 0.192308 & 0.548077 \\
# 2 & 309.177570 & 103.523364 & 2.705607 & 2.925234 & 8.183738 & 0.299065 & 0.625981 \\
# 3 & 315.954887 & 106.887218 & 3.364662 & 3.402256 & 8.552256 & 0.533835 & 0.711880 \\
# 4 & 324.824324 & 111.824324 & 4.108108 & 4.006757 & 9.021622 & 0.797297 & 0.818108 \\
# 5 & 328.333333 & 113.666667 & 4.500000 & 4.358333 & 9.291167 & 0.866667 & 0.888167 \\
# \end{tabular}

# %%
print(means_by_rating.to_latex(index=True))
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# {} &   GRE Score &  TOEFL Score &       SOP &      LOR  &      CGPA &  Research &  Chance of Admit  \\
# University Rating &             &              &           &           &           &           &                   \\
# \midrule
# 1                 &  303.153846 &    99.076923 &  1.884615 &  2.211538 &  7.745769 &  0.192308 &          0.548077 \\
# 2                 &  309.177570 &   103.523364 &  2.705607 &  2.925234 &  8.183738 &  0.299065 &          0.625981 \\
# 3                 &  315.954887 &   106.887218 &  3.364662 &  3.402256 &  8.552256 &  0.533835 &          0.711880 \\
# 4                 &  324.824324 &   111.824324 &  4.108108 &  4.006757 &  9.021622 &  0.797297 &          0.818108 \\
# 5                 &  328.333333 &   113.666667 &  4.500000 &  4.358333 &  9.291167 &  0.866667 &          0.888167 \\
# \bottomrule
# \end{tabular}
# ...

# %%
amd_data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
amd_data["GRE norm Score"]=amd_data["GRE Score"]/340
amd_data["TOEFL norm Score"]=amd_data["TOEFL Score"]/120

# %%
amd_data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit   GRE norm Score  TOEFL norm Score
# ...

# %%
import matplotlib.pyplot as plt
amd_data["GRE norm Score"].hist(alpha=0.75,label="GRE", color="green")
amd_data["TOEFL norm Score"].hist(alpha=0.5, label="TOEFL", color="blue")
plt.legend()
plt.xlabel("Normalized Score")
plt.ylabel("La mejor materia del mundo: HIGI2022")

plt.savefig("/home/vegaal2021/Documents/v3ga/Histograma2.pdf")
